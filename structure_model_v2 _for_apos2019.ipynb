# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

# %%
# ================== CONFIG ==================
TRAIN_DIR = "aptos2019-blindness-detection/train"
VAL_DIR   = "aptos2019-blindness-detection/val"

IMAGE_SIZE = 448       # 448 hoặc 512 cho CPU; 600 sẽ rất chậm trên CPU
BATCH_SIZE = 8
SEED = 42

FREEZE_BACKBONE = True   # freeze giai đoạn đầu cho CPU
DROP_RATE = 0.4          # dropout trong head
DENSE_UNITS = 1024

LR = 3e-4
WEIGHT_DECAY = 1e-4
LOSS_W_SOFTMAX = 1.0
LOSS_W_ORDINAL = 0.5

EPOCHS = 20              # ví dụ (bạn tăng sau)

# %%
AUTOTUNE = tf.data.AUTOTUNE
from tensorflow.keras.applications.efficientnet import preprocess_input, EfficientNetB4

# %%
# ========== Ordinal utils ==========
def ordinal_encode_tf(y_int):
    """y_int: (B,) int32 0..4 -> (B,4) float32: [y>=1, y>=2, y>=3, y>=4]"""
    y_int = tf.cast(y_int, tf.int32)
    thresholds = tf.constant([1, 2, 3, 4], dtype=tf.int32)  # (4,)
    y_exp = tf.expand_dims(y_int, axis=-1)                  # (B,1)
    return tf.cast(y_exp >= thresholds, tf.float32)         # (B,4)

def map_preprocess(image, label):
    # image_dataset_from_directory trả image uint8 [0..255]; EfficientNet preprocess sẽ scale
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)  # -> [0..1] cho EfficientNet
    return image, label

def map_dual_targets(image, y_int):
    # tạo 2 nhãn: softmax (int) và ordinal (4-dim)
    return image, {
        "softmax": tf.cast(y_int, tf.int32),
        "ordinal": ordinal_encode_tf(y_int)
    }

# %%
# ========== Dataset loaders (không cache vào RAM) ==========
def make_ds(data_dir, subset="train"):
    ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        labels="inferred",
        label_mode="int",
        class_names=["0","1","2","3","4"],   # cố định thứ tự nhãn
        color_mode="rgb",
        batch_size=BATCH_SIZE,
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        shuffle=(subset=="train"),
        seed=SEED
    )
    ds = ds.map(map_preprocess, num_parallel_calls=AUTOTUNE)
    ds = ds.map(map_dual_targets, num_parallel_calls=AUTOTUNE)
    # Không dùng .cache() để tiết kiệm RAM; chỉ prefetch
    ds = ds.prefetch(AUTOTUNE)
    return ds

# %%
def sca_block(x, ratio=8, name="sca"):
    """Simple Channel Attention: GAP -> 1x1 Conv (reduce) -> 1x1 Conv (gate sigmoid) -> multiply."""
    ch = int(x.shape[-1])
    mid = max(ch // ratio, 1)

    gap = layers.GlobalAveragePooling2D(keepdims=True, name=f"{name}_gap")(x)
    red = layers.Conv2D(mid, 1, padding="same", activation="relu",
                        use_bias=True, name=f"{name}_reduce")(gap)
    gate = layers.Conv2D(ch, 1, padding="same", activation="sigmoid",
                         use_bias=True, name=f"{name}_gate")(red)
    out = layers.Multiply(name=f"{name}_mul")([x, gate])
    return out

# %%
# ===== CBAM: ChannelAttention + SpatialAttention (no Lambda) =====
from tensorflow import keras

class ChannelAttention(layers.Layer):
    def __init__(self, ratio=8, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.ratio = ratio
        # các layer con sẽ khởi tạo trong build()

    def build(self, input_shape):
        ch = int(input_shape[-1])
        mid = max(ch // self.ratio, 1)
        # Pooling theo không gian, giữ (1,1,C)
        self.gap = layers.GlobalAveragePooling2D(keepdims=True, name=f"{self.name}_gap")
        self.gmp = layers.GlobalMaxPooling2D(keepdims=True,        name=f"{self.name}_gmp")
        # Shared MLP dùng Conv1x1 trên (1,1,C)
        self.mlp1 = layers.Conv2D(mid, 1, padding="same", activation="relu", use_bias=True, name=f"{self.name}_mlp1")
        self.mlp2 = layers.Conv2D(ch,  1, padding="same", activation="sigmoid", use_bias=True, name=f"{self.name}_mlp2")

    def call(self, x):
        # 2 nhánh: GAP và GMP -> shared MLP -> cộng -> gate
        avg_att = self.mlp2(self.mlp1(self.gap(x)))
        max_att = self.mlp2(self.mlp1(self.gmp(x)))
        gate = avg_att + max_att
        return x * gate  # broadcast theo (H,W,C)

class SpatialAttention(layers.Layer):
    def __init__(self, kernel_size=7, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.kernel_size = kernel_size

    def build(self, input_shape):
        self.conv = layers.Conv2D(
            1, self.kernel_size, padding="same",
            activation="sigmoid", use_bias=False, name=f"{self.name}_conv"
        )

    def call(self, x):
        # Tính trung bình & cực đại theo kênh (không dùng Lambda)
        avg_map = tf.reduce_mean(x, axis=-1, keepdims=True)  # (B,H,W,1)
        max_map = tf.reduce_max(x,  axis=-1, keepdims=True)  # (B,H,W,1)
        concat  = tf.concat([avg_map, max_map], axis=-1)     # (B,H,W,2)
        att_map = self.conv(concat)                          # (B,H,W,1)
        return x * att_map

def cbam_block(x, ratio=8, ksize=7, name="cbam"):
    x = ChannelAttention(ratio=ratio, name=f"{name}_ch")(x)
    x = SpatialAttention(kernel_size=ksize, name=f"{name}_sp")(x)
    return x

# %%
# ========== Model builder ==========
def build_model(img_size=IMAGE_SIZE, freeze_backbone=FREEZE_BACKBONE):
    inputs = layers.Input(shape=(img_size, img_size, 3))

    # Backbone EfficientNet-B4 (ImageNet)
    base = EfficientNetB4(include_top=False, weights="imagenet", input_tensor=inputs)
    base.trainable = not freeze_backbone

    x = base.output
    # CBAM ở feature map cuối (nhẹ)
    x = cbam_block(x, ratio=8, ksize=7, name="cbam_c5") 
    # SCA ở feature map cuối (nhẹ)
    # x = sca_block(x, ratio=8, name="sca") #dung sca

    # Global pooling + head chung
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(DROP_RATE)(x)
    x = layers.Dense(DENSE_UNITS, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(DROP_RATE * 0.75)(x)

    # Head A: Softmax 5 lớp
    out_soft = layers.Dense(5, activation="softmax", name="softmax")(x)
    # Head B: Ordinal (≥1..4), sigmoid
    out_ord  = layers.Dense(4, activation="sigmoid", name="ordinal")(x)

    model = models.Model(inputs, [out_soft, out_ord], name="EffB4_CBAM_DualHead")
    return model

# %%
# ========== Compile ==========
def compile_model(model,
                  lr=LR,
                  wd=WEIGHT_DECAY,
                  loss_w_softmax=LOSS_W_SOFTMAX,
                  loss_w_ordinal=LOSS_W_ORDINAL):
    try:
        optimizer = tf.keras.optimizers.AdamW(learning_rate=lr, weight_decay=wd)
    except Exception:
        optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    losses = {
        "softmax": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        "ordinal": tf.keras.losses.BinaryCrossentropy(from_logits=False),
    }
    loss_weights = {"softmax": loss_w_softmax, "ordinal": loss_w_ordinal}

    metrics = {
        "softmax": [tf.keras.metrics.SparseCategoricalAccuracy(name="acc")],
        "ordinal": [tf.keras.metrics.AUC(name="auc", multi_label=True)],
    }

    model.compile(optimizer=optimizer, loss=losses,
                  loss_weights=loss_weights, metrics=metrics)
    return model

# %%
# ================== MAIN ==================

print("Loading datasets...")
ds_train = make_ds(TRAIN_DIR, subset="train")
ds_val   = make_ds(VAL_DIR, subset="val")

print("Building model...")
model = build_model()
model = compile_model(model)

model.summary(line_length=120)

    # Giai đoạn 1: (khuyên dùng cho CPU) train head với backbone freeze
callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
        tf.keras.callbacks.ModelCheckpoint("models/effb4_apos2019_dualhead_stage1.keras",
                                           monitor="val_loss", save_best_only=True)
    ]
# Out:
# Loading datasets...
# Found 2931 files belonging to 5 classes.
# Found 731 files belonging to 5 classes.
# Building model...
# Model: "EffB4_CBAM_DualHead"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ┃ Layer (type)                      ┃ Output Shape                 ┃           Param # ┃ Connected to
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━
# │ input_layer_1 (InputLayer)        │ (None, 448, 448, 3)          │                 0 │ -
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ rescaling_2 (Rescaling)           │ (None, 448, 448, 3)          │                 0 │ input_layer_1[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ normalization_1 (Normalization)   │ (None, 448, 448, 3)          │                 7 │ rescaling_2[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ rescaling_3 (Rescaling)           │ (None, 448, 448, 3)          │                 0 │ normalization_1[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ stem_conv_pad (ZeroPadding2D)     │ (None, 449, 449, 3)          │                 0 │ rescaling_3[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ stem_conv (Conv2D)                │ (None, 224, 224, 48)         │             1,296 │ stem_conv_pad[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ stem_bn (BatchNormalization)      │ (None, 224, 224, 48)         │               192 │ stem_conv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ stem_activation (Activation)      │ (None, 224, 224, 48)         │                 0 │ stem_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_dwconv (DepthwiseConv2D)  │ (None, 224, 224, 48)         │               432 │ stem_activation[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_bn (BatchNormalization)   │ (None, 224, 224, 48)         │               192 │ block1a_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_activation (Activation)   │ (None, 224, 224, 48)         │                 0 │ block1a_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_se_squeeze                │ (None, 48)                   │                 0 │ block1a_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_se_reshape (Reshape)      │ (None, 1, 1, 48)             │                 0 │ block1a_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_se_reduce (Conv2D)        │ (None, 1, 1, 12)             │               588 │ block1a_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_se_expand (Conv2D)        │ (None, 1, 1, 48)             │               624 │ block1a_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_se_excite (Multiply)      │ (None, 224, 224, 48)         │                 0 │ block1a_activation[0][0],
# │                                   │                              │                   │ block1a_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_project_conv (Conv2D)     │ (None, 224, 224, 24)         │             1,152 │ block1a_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1a_project_bn                │ (None, 224, 224, 24)         │                96 │ block1a_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_dwconv (DepthwiseConv2D)  │ (None, 224, 224, 24)         │               216 │ block1a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_bn (BatchNormalization)   │ (None, 224, 224, 24)         │                96 │ block1b_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_activation (Activation)   │ (None, 224, 224, 24)         │                 0 │ block1b_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_se_squeeze                │ (None, 24)                   │                 0 │ block1b_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_se_reshape (Reshape)      │ (None, 1, 1, 24)             │                 0 │ block1b_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_se_reduce (Conv2D)        │ (None, 1, 1, 6)              │               150 │ block1b_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_se_expand (Conv2D)        │ (None, 1, 1, 24)             │               168 │ block1b_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_se_excite (Multiply)      │ (None, 224, 224, 24)         │                 0 │ block1b_activation[0][0],
# │                                   │                              │                   │ block1b_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_project_conv (Conv2D)     │ (None, 224, 224, 24)         │               576 │ block1b_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_project_bn                │ (None, 224, 224, 24)         │                96 │ block1b_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_drop (Dropout)            │ (None, 224, 224, 24)         │                 0 │ block1b_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block1b_add (Add)                 │ (None, 224, 224, 24)         │                 0 │ block1b_drop[0][0],
# │                                   │                              │                   │ block1a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_expand_conv (Conv2D)      │ (None, 224, 224, 144)        │             3,456 │ block1b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_expand_bn                 │ (None, 224, 224, 144)        │               576 │ block2a_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_expand_activation         │ (None, 224, 224, 144)        │                 0 │ block2a_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_dwconv_pad                │ (None, 225, 225, 144)        │                 0 │ block2a_expand_activation[
# │ (ZeroPadding2D)                   │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_dwconv (DepthwiseConv2D)  │ (None, 112, 112, 144)        │             1,296 │ block2a_dwconv_pad[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_bn (BatchNormalization)   │ (None, 112, 112, 144)        │               576 │ block2a_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_activation (Activation)   │ (None, 112, 112, 144)        │                 0 │ block2a_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_se_squeeze                │ (None, 144)                  │                 0 │ block2a_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_se_reshape (Reshape)      │ (None, 1, 1, 144)            │                 0 │ block2a_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_se_reduce (Conv2D)        │ (None, 1, 1, 6)              │               870 │ block2a_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_se_expand (Conv2D)        │ (None, 1, 1, 144)            │             1,008 │ block2a_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_se_excite (Multiply)      │ (None, 112, 112, 144)        │                 0 │ block2a_activation[0][0],
# │                                   │                              │                   │ block2a_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_project_conv (Conv2D)     │ (None, 112, 112, 32)         │             4,608 │ block2a_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2a_project_bn                │ (None, 112, 112, 32)         │               128 │ block2a_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_expand_conv (Conv2D)      │ (None, 112, 112, 192)        │             6,144 │ block2a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_expand_bn                 │ (None, 112, 112, 192)        │               768 │ block2b_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_expand_activation         │ (None, 112, 112, 192)        │                 0 │ block2b_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_dwconv (DepthwiseConv2D)  │ (None, 112, 112, 192)        │             1,728 │ block2b_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_bn (BatchNormalization)   │ (None, 112, 112, 192)        │               768 │ block2b_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_activation (Activation)   │ (None, 112, 112, 192)        │                 0 │ block2b_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_se_squeeze                │ (None, 192)                  │                 0 │ block2b_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_se_reshape (Reshape)      │ (None, 1, 1, 192)            │                 0 │ block2b_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_se_reduce (Conv2D)        │ (None, 1, 1, 8)              │             1,544 │ block2b_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_se_expand (Conv2D)        │ (None, 1, 1, 192)            │             1,728 │ block2b_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_se_excite (Multiply)      │ (None, 112, 112, 192)        │                 0 │ block2b_activation[0][0],
# │                                   │                              │                   │ block2b_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_project_conv (Conv2D)     │ (None, 112, 112, 32)         │             6,144 │ block2b_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_project_bn                │ (None, 112, 112, 32)         │               128 │ block2b_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_drop (Dropout)            │ (None, 112, 112, 32)         │                 0 │ block2b_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2b_add (Add)                 │ (None, 112, 112, 32)         │                 0 │ block2b_drop[0][0],
# │                                   │                              │                   │ block2a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_expand_conv (Conv2D)      │ (None, 112, 112, 192)        │             6,144 │ block2b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_expand_bn                 │ (None, 112, 112, 192)        │               768 │ block2c_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_expand_activation         │ (None, 112, 112, 192)        │                 0 │ block2c_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_dwconv (DepthwiseConv2D)  │ (None, 112, 112, 192)        │             1,728 │ block2c_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_bn (BatchNormalization)   │ (None, 112, 112, 192)        │               768 │ block2c_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_activation (Activation)   │ (None, 112, 112, 192)        │                 0 │ block2c_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_se_squeeze                │ (None, 192)                  │                 0 │ block2c_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_se_reshape (Reshape)      │ (None, 1, 1, 192)            │                 0 │ block2c_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_se_reduce (Conv2D)        │ (None, 1, 1, 8)              │             1,544 │ block2c_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_se_expand (Conv2D)        │ (None, 1, 1, 192)            │             1,728 │ block2c_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_se_excite (Multiply)      │ (None, 112, 112, 192)        │                 0 │ block2c_activation[0][0],
# │                                   │                              │                   │ block2c_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_project_conv (Conv2D)     │ (None, 112, 112, 32)         │             6,144 │ block2c_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_project_bn                │ (None, 112, 112, 32)         │               128 │ block2c_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_drop (Dropout)            │ (None, 112, 112, 32)         │                 0 │ block2c_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2c_add (Add)                 │ (None, 112, 112, 32)         │                 0 │ block2c_drop[0][0],
# │                                   │                              │                   │ block2b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_expand_conv (Conv2D)      │ (None, 112, 112, 192)        │             6,144 │ block2c_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_expand_bn                 │ (None, 112, 112, 192)        │               768 │ block2d_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_expand_activation         │ (None, 112, 112, 192)        │                 0 │ block2d_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_dwconv (DepthwiseConv2D)  │ (None, 112, 112, 192)        │             1,728 │ block2d_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_bn (BatchNormalization)   │ (None, 112, 112, 192)        │               768 │ block2d_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_activation (Activation)   │ (None, 112, 112, 192)        │                 0 │ block2d_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_se_squeeze                │ (None, 192)                  │                 0 │ block2d_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_se_reshape (Reshape)      │ (None, 1, 1, 192)            │                 0 │ block2d_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_se_reduce (Conv2D)        │ (None, 1, 1, 8)              │             1,544 │ block2d_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_se_expand (Conv2D)        │ (None, 1, 1, 192)            │             1,728 │ block2d_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_se_excite (Multiply)      │ (None, 112, 112, 192)        │                 0 │ block2d_activation[0][0],
# │                                   │                              │                   │ block2d_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_project_conv (Conv2D)     │ (None, 112, 112, 32)         │             6,144 │ block2d_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_project_bn                │ (None, 112, 112, 32)         │               128 │ block2d_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_drop (Dropout)            │ (None, 112, 112, 32)         │                 0 │ block2d_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block2d_add (Add)                 │ (None, 112, 112, 32)         │                 0 │ block2d_drop[0][0],
# │                                   │                              │                   │ block2c_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_expand_conv (Conv2D)      │ (None, 112, 112, 192)        │             6,144 │ block2d_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_expand_bn                 │ (None, 112, 112, 192)        │               768 │ block3a_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_expand_activation         │ (None, 112, 112, 192)        │                 0 │ block3a_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_dwconv_pad                │ (None, 115, 115, 192)        │                 0 │ block3a_expand_activation[
# │ (ZeroPadding2D)                   │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_dwconv (DepthwiseConv2D)  │ (None, 56, 56, 192)          │             4,800 │ block3a_dwconv_pad[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_bn (BatchNormalization)   │ (None, 56, 56, 192)          │               768 │ block3a_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_activation (Activation)   │ (None, 56, 56, 192)          │                 0 │ block3a_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_se_squeeze                │ (None, 192)                  │                 0 │ block3a_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_se_reshape (Reshape)      │ (None, 1, 1, 192)            │                 0 │ block3a_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_se_reduce (Conv2D)        │ (None, 1, 1, 8)              │             1,544 │ block3a_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_se_expand (Conv2D)        │ (None, 1, 1, 192)            │             1,728 │ block3a_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_se_excite (Multiply)      │ (None, 56, 56, 192)          │                 0 │ block3a_activation[0][0],
# │                                   │                              │                   │ block3a_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_project_conv (Conv2D)     │ (None, 56, 56, 56)           │            10,752 │ block3a_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3a_project_bn                │ (None, 56, 56, 56)           │               224 │ block3a_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_expand_conv (Conv2D)      │ (None, 56, 56, 336)          │            18,816 │ block3a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_expand_bn                 │ (None, 56, 56, 336)          │             1,344 │ block3b_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_expand_activation         │ (None, 56, 56, 336)          │                 0 │ block3b_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_dwconv (DepthwiseConv2D)  │ (None, 56, 56, 336)          │             8,400 │ block3b_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_bn (BatchNormalization)   │ (None, 56, 56, 336)          │             1,344 │ block3b_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_activation (Activation)   │ (None, 56, 56, 336)          │                 0 │ block3b_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_se_squeeze                │ (None, 336)                  │                 0 │ block3b_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_se_reshape (Reshape)      │ (None, 1, 1, 336)            │                 0 │ block3b_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_se_reduce (Conv2D)        │ (None, 1, 1, 14)             │             4,718 │ block3b_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_se_expand (Conv2D)        │ (None, 1, 1, 336)            │             5,040 │ block3b_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_se_excite (Multiply)      │ (None, 56, 56, 336)          │                 0 │ block3b_activation[0][0],
# │                                   │                              │                   │ block3b_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_project_conv (Conv2D)     │ (None, 56, 56, 56)           │            18,816 │ block3b_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_project_bn                │ (None, 56, 56, 56)           │               224 │ block3b_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_drop (Dropout)            │ (None, 56, 56, 56)           │                 0 │ block3b_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3b_add (Add)                 │ (None, 56, 56, 56)           │                 0 │ block3b_drop[0][0],
# │                                   │                              │                   │ block3a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_expand_conv (Conv2D)      │ (None, 56, 56, 336)          │            18,816 │ block3b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_expand_bn                 │ (None, 56, 56, 336)          │             1,344 │ block3c_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_expand_activation         │ (None, 56, 56, 336)          │                 0 │ block3c_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_dwconv (DepthwiseConv2D)  │ (None, 56, 56, 336)          │             8,400 │ block3c_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_bn (BatchNormalization)   │ (None, 56, 56, 336)          │             1,344 │ block3c_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_activation (Activation)   │ (None, 56, 56, 336)          │                 0 │ block3c_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_se_squeeze                │ (None, 336)                  │                 0 │ block3c_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_se_reshape (Reshape)      │ (None, 1, 1, 336)            │                 0 │ block3c_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_se_reduce (Conv2D)        │ (None, 1, 1, 14)             │             4,718 │ block3c_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_se_expand (Conv2D)        │ (None, 1, 1, 336)            │             5,040 │ block3c_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_se_excite (Multiply)      │ (None, 56, 56, 336)          │                 0 │ block3c_activation[0][0],
# │                                   │                              │                   │ block3c_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_project_conv (Conv2D)     │ (None, 56, 56, 56)           │            18,816 │ block3c_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_project_bn                │ (None, 56, 56, 56)           │               224 │ block3c_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_drop (Dropout)            │ (None, 56, 56, 56)           │                 0 │ block3c_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3c_add (Add)                 │ (None, 56, 56, 56)           │                 0 │ block3c_drop[0][0],
# │                                   │                              │                   │ block3b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_expand_conv (Conv2D)      │ (None, 56, 56, 336)          │            18,816 │ block3c_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_expand_bn                 │ (None, 56, 56, 336)          │             1,344 │ block3d_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_expand_activation         │ (None, 56, 56, 336)          │                 0 │ block3d_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_dwconv (DepthwiseConv2D)  │ (None, 56, 56, 336)          │             8,400 │ block3d_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_bn (BatchNormalization)   │ (None, 56, 56, 336)          │             1,344 │ block3d_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_activation (Activation)   │ (None, 56, 56, 336)          │                 0 │ block3d_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_se_squeeze                │ (None, 336)                  │                 0 │ block3d_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_se_reshape (Reshape)      │ (None, 1, 1, 336)            │                 0 │ block3d_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_se_reduce (Conv2D)        │ (None, 1, 1, 14)             │             4,718 │ block3d_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_se_expand (Conv2D)        │ (None, 1, 1, 336)            │             5,040 │ block3d_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_se_excite (Multiply)      │ (None, 56, 56, 336)          │                 0 │ block3d_activation[0][0],
# │                                   │                              │                   │ block3d_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_project_conv (Conv2D)     │ (None, 56, 56, 56)           │            18,816 │ block3d_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_project_bn                │ (None, 56, 56, 56)           │               224 │ block3d_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_drop (Dropout)            │ (None, 56, 56, 56)           │                 0 │ block3d_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block3d_add (Add)                 │ (None, 56, 56, 56)           │                 0 │ block3d_drop[0][0],
# │                                   │                              │                   │ block3c_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_expand_conv (Conv2D)      │ (None, 56, 56, 336)          │            18,816 │ block3d_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_expand_bn                 │ (None, 56, 56, 336)          │             1,344 │ block4a_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_expand_activation         │ (None, 56, 56, 336)          │                 0 │ block4a_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_dwconv_pad                │ (None, 57, 57, 336)          │                 0 │ block4a_expand_activation[
# │ (ZeroPadding2D)                   │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_dwconv (DepthwiseConv2D)  │ (None, 28, 28, 336)          │             3,024 │ block4a_dwconv_pad[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_bn (BatchNormalization)   │ (None, 28, 28, 336)          │             1,344 │ block4a_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_activation (Activation)   │ (None, 28, 28, 336)          │                 0 │ block4a_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_se_squeeze                │ (None, 336)                  │                 0 │ block4a_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_se_reshape (Reshape)      │ (None, 1, 1, 336)            │                 0 │ block4a_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_se_reduce (Conv2D)        │ (None, 1, 1, 14)             │             4,718 │ block4a_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_se_expand (Conv2D)        │ (None, 1, 1, 336)            │             5,040 │ block4a_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_se_excite (Multiply)      │ (None, 28, 28, 336)          │                 0 │ block4a_activation[0][0],
# │                                   │                              │                   │ block4a_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_project_conv (Conv2D)     │ (None, 28, 28, 112)          │            37,632 │ block4a_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4a_project_bn                │ (None, 28, 28, 112)          │               448 │ block4a_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_expand_conv (Conv2D)      │ (None, 28, 28, 672)          │            75,264 │ block4a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_expand_bn                 │ (None, 28, 28, 672)          │             2,688 │ block4b_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_expand_activation         │ (None, 28, 28, 672)          │                 0 │ block4b_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_dwconv (DepthwiseConv2D)  │ (None, 28, 28, 672)          │             6,048 │ block4b_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_bn (BatchNormalization)   │ (None, 28, 28, 672)          │             2,688 │ block4b_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_activation (Activation)   │ (None, 28, 28, 672)          │                 0 │ block4b_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_se_squeeze                │ (None, 672)                  │                 0 │ block4b_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_se_reshape (Reshape)      │ (None, 1, 1, 672)            │                 0 │ block4b_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_se_reduce (Conv2D)        │ (None, 1, 1, 28)             │            18,844 │ block4b_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_se_expand (Conv2D)        │ (None, 1, 1, 672)            │            19,488 │ block4b_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block4b_se_excite (Multiply)      │ (None, 28, 28, 672)          │                 0 │ block4b_activation[0][0],
# ...
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6g_add (Add)                 │ (None, 14, 14, 272)          │                 0 │ block6g_drop[0][0],
# │                                   │                              │                   │ block6f_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_expand_conv (Conv2D)      │ (None, 14, 14, 1632)         │           443,904 │ block6g_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_expand_bn                 │ (None, 14, 14, 1632)         │             6,528 │ block6h_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_expand_activation         │ (None, 14, 14, 1632)         │                 0 │ block6h_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_dwconv (DepthwiseConv2D)  │ (None, 14, 14, 1632)         │            40,800 │ block6h_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_bn (BatchNormalization)   │ (None, 14, 14, 1632)         │             6,528 │ block6h_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_activation (Activation)   │ (None, 14, 14, 1632)         │                 0 │ block6h_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_se_squeeze                │ (None, 1632)                 │                 0 │ block6h_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_se_reshape (Reshape)      │ (None, 1, 1, 1632)           │                 0 │ block6h_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_se_reduce (Conv2D)        │ (None, 1, 1, 68)             │           111,044 │ block6h_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_se_expand (Conv2D)        │ (None, 1, 1, 1632)           │           112,608 │ block6h_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_se_excite (Multiply)      │ (None, 14, 14, 1632)         │                 0 │ block6h_activation[0][0],
# │                                   │                              │                   │ block6h_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_project_conv (Conv2D)     │ (None, 14, 14, 272)          │           443,904 │ block6h_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_project_bn                │ (None, 14, 14, 272)          │             1,088 │ block6h_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_drop (Dropout)            │ (None, 14, 14, 272)          │                 0 │ block6h_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block6h_add (Add)                 │ (None, 14, 14, 272)          │                 0 │ block6h_drop[0][0],
# │                                   │                              │                   │ block6g_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_expand_conv (Conv2D)      │ (None, 14, 14, 1632)         │           443,904 │ block6h_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_expand_bn                 │ (None, 14, 14, 1632)         │             6,528 │ block7a_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_expand_activation         │ (None, 14, 14, 1632)         │                 0 │ block7a_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_dwconv (DepthwiseConv2D)  │ (None, 14, 14, 1632)         │            14,688 │ block7a_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_bn (BatchNormalization)   │ (None, 14, 14, 1632)         │             6,528 │ block7a_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_activation (Activation)   │ (None, 14, 14, 1632)         │                 0 │ block7a_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_se_squeeze                │ (None, 1632)                 │                 0 │ block7a_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_se_reshape (Reshape)      │ (None, 1, 1, 1632)           │                 0 │ block7a_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_se_reduce (Conv2D)        │ (None, 1, 1, 68)             │           111,044 │ block7a_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_se_expand (Conv2D)        │ (None, 1, 1, 1632)           │           112,608 │ block7a_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_se_excite (Multiply)      │ (None, 14, 14, 1632)         │                 0 │ block7a_activation[0][0],
# │                                   │                              │                   │ block7a_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_project_conv (Conv2D)     │ (None, 14, 14, 448)          │           731,136 │ block7a_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7a_project_bn                │ (None, 14, 14, 448)          │             1,792 │ block7a_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_expand_conv (Conv2D)      │ (None, 14, 14, 2688)         │         1,204,224 │ block7a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_expand_bn                 │ (None, 14, 14, 2688)         │            10,752 │ block7b_expand_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_expand_activation         │ (None, 14, 14, 2688)         │                 0 │ block7b_expand_bn[0][0]
# │ (Activation)                      │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_dwconv (DepthwiseConv2D)  │ (None, 14, 14, 2688)         │            24,192 │ block7b_expand_activation[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_bn (BatchNormalization)   │ (None, 14, 14, 2688)         │            10,752 │ block7b_dwconv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_activation (Activation)   │ (None, 14, 14, 2688)         │                 0 │ block7b_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_se_squeeze                │ (None, 2688)                 │                 0 │ block7b_activation[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_se_reshape (Reshape)      │ (None, 1, 1, 2688)           │                 0 │ block7b_se_squeeze[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_se_reduce (Conv2D)        │ (None, 1, 1, 112)            │           301,168 │ block7b_se_reshape[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_se_expand (Conv2D)        │ (None, 1, 1, 2688)           │           303,744 │ block7b_se_reduce[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_se_excite (Multiply)      │ (None, 14, 14, 2688)         │                 0 │ block7b_activation[0][0],
# │                                   │                              │                   │ block7b_se_expand[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_project_conv (Conv2D)     │ (None, 14, 14, 448)          │         1,204,224 │ block7b_se_excite[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_project_bn                │ (None, 14, 14, 448)          │             1,792 │ block7b_project_conv[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_drop (Dropout)            │ (None, 14, 14, 448)          │                 0 │ block7b_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block7b_add (Add)                 │ (None, 14, 14, 448)          │                 0 │ block7b_drop[0][0],
# │                                   │                              │                   │ block7a_project_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ top_conv (Conv2D)                 │ (None, 14, 14, 1792)         │           802,816 │ block7b_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ top_bn (BatchNormalization)       │ (None, 14, 14, 1792)         │             7,168 │ top_conv[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ top_activation (Activation)       │ (None, 14, 14, 1792)         │                 0 │ top_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ cbam_c5_ch (ChannelAttention)     │ (None, 14, 14, 1792)         │           804,832 │ top_activation[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ cbam_c5_sp (SpatialAttention)     │ (None, 14, 14, 1792)         │                98 │ cbam_c5_ch[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ global_average_pooling2d_1        │ (None, 1792)                 │                 0 │ cbam_c5_sp[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_2             │ (None, 1792)                 │             7,168 │ global_average_pooling2d_1
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_2 (Dropout)               │ (None, 1792)                 │                 0 │ batch_normalization_2[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dense_1 (Dense)                   │ (None, 1024)                 │         1,836,032 │ dropout_2[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_3             │ (None, 1024)                 │             4,096 │ dense_1[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_3 (Dropout)               │ (None, 1024)                 │                 0 │ batch_normalization_3[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ softmax (Dense)                   │ (None, 5)                    │             5,125 │ dropout_3[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ ordinal (Dense)                   │ (None, 4)                    │             4,100 │ dropout_3[0][0]
# └───────────────────────────────────┴──────────────────────────────┴───────────────────┴───────────────────────────
#  Total params: 20,335,274 (77.57 MB)
#  Trainable params: 2,655,819 (10.13 MB)
#  Non-trainable params: 17,679,455 (67.44 MB)

# %%
print("\n=== Stage 1: Train head (backbone frozen) ===")
history1 = model.fit(
        ds_train,
        validation_data=ds_val,
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )
# Out:
# === Stage 1: Train head (backbone frozen) ===
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755060123.371263   10405 service.cc:152] XLA service 0x7bd818002710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755060123.371292   10405 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-08-13 00:42:04.289663: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755060127.187103   10405 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-13 00:42:12.407368: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-13 00:42:12.555984: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/367 ━━━━━━━━━━━━━━━━━━━━ 3:51:54 38s/step - loss: 3.6179 - ordinal_auc: 0.4621 - ordinal_loss: 1.0959 - softmax_acc: 0.1250 - softmax_loss: 3.0700
# I0000 00:00:1755060149.889860   10405 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 366/367 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.7699 - ordinal_auc: 0.7243 - ordinal_loss: 0.6664 - softmax_acc: 0.5874 - softmax_loss: 1.4367
# 2025-08-13 00:43:14.111639: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-13 00:43:14.245026: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 119s 220ms/step - loss: 1.7686 - ordinal_auc: 0.7246 - ordinal_loss: 0.6658 - softmax_acc: 0.5876 - softmax_loss: 1.4357 - val_loss: 0.7676 - val_ordinal_auc: 0.9207 - val_ordinal_loss: 0.2969 - val_softmax_acc: 0.7620 - val_softmax_loss: 0.6215 - learning_rate: 3.0000e-04
# Epoch 2/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 127ms/step - loss: 1.2294 - ordinal_auc: 0.8236 - ordinal_loss: 0.4260 - softmax_acc: 0.6833 - softmax_loss: 1.0163 - val_loss: 0.9834 - val_ordinal_auc: 0.9320 - val_ordinal_loss: 0.2273 - val_softmax_acc: 0.7428 - val_softmax_loss: 0.8874 - learning_rate: 3.0000e-04
# Epoch 3/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 48s 130ms/step - loss: 1.0496 - ordinal_auc: 0.8393 - ordinal_loss: 0.3419 - softmax_acc: 0.7284 - softmax_loss: 0.8786 - val_loss: 0.7233 - val_ordinal_auc: 0.9442 - val_ordinal_loss: 0.2089 - val_softmax_acc: 0.7715 - val_softmax_loss: 0.6312 - learning_rate: 3.0000e-04
# Epoch 4/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.8718 - ordinal_auc: 0.8778 - ordinal_loss: 0.2787 - softmax_acc: 0.7496 - softmax_loss: 0.7324 - val_loss: 0.7329 - val_ordinal_auc: 0.9452 - val_ordinal_loss: 0.1758 - val_softmax_acc: 0.7866 - val_softmax_loss: 0.6499 - learning_rate: 3.0000e-04
# Epoch 5/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - loss: 0.8982 - ordinal_auc: 0.8873 - ordinal_loss: 0.2694 - softmax_acc: 0.7340 - softmax_loss: 0.7635 - val_loss: 0.6739 - val_ordinal_auc: 0.9540 - val_ordinal_loss: 0.1648 - val_softmax_acc: 0.8030 - val_softmax_loss: 0.5992 - learning_rate: 3.0000e-04
# Epoch 6/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - loss: 0.8387 - ordinal_auc: 0.8962 - ordinal_loss: 0.2552 - softmax_acc: 0.7512 - softmax_loss: 0.7111 - val_loss: 0.6473 - val_ordinal_auc: 0.9483 - val_ordinal_loss: 0.1656 - val_softmax_acc: 0.8044 - val_softmax_loss: 0.5731 - learning_rate: 3.0000e-04
# Epoch 7/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.8085 - ordinal_auc: 0.9023 - ordinal_loss: 0.2491 - softmax_acc: 0.7471 - softmax_loss: 0.6839 - val_loss: 0.7003 - val_ordinal_auc: 0.9483 - val_ordinal_loss: 0.1716 - val_softmax_acc: 0.7811 - val_softmax_loss: 0.6181 - learning_rate: 3.0000e-04
# Epoch 8/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.8419 - ordinal_auc: 0.9068 - ordinal_loss: 0.2561 - softmax_acc: 0.7397 - softmax_loss: 0.7139 - val_loss: 0.6558 - val_ordinal_auc: 0.9523 - val_ordinal_loss: 0.1624 - val_softmax_acc: 0.8057 - val_softmax_loss: 0.5826 - learning_rate: 3.0000e-04
# Epoch 9/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - loss: 0.7569 - ordinal_auc: 0.9080 - ordinal_loss: 0.2387 - softmax_acc: 0.7701 - softmax_loss: 0.6376 - val_loss: 0.5985 - val_ordinal_auc: 0.9578 - val_ordinal_loss: 0.1539 - val_softmax_acc: 0.8153 - val_softmax_loss: 0.5328 - learning_rate: 3.0000e-04
# Epoch 10/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.7150 - ordinal_auc: 0.9317 - ordinal_loss: 0.2188 - softmax_acc: 0.7751 - softmax_loss: 0.6056 - val_loss: 0.6345 - val_ordinal_auc: 0.9546 - val_ordinal_loss: 0.1628 - val_softmax_acc: 0.7989 - val_softmax_loss: 0.5669 - learning_rate: 3.0000e-04
# Epoch 11/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - loss: 0.6837 - ordinal_auc: 0.9365 - ordinal_loss: 0.2108 - softmax_acc: 0.7897 - softmax_loss: 0.5783 - val_loss: 0.6679 - val_ordinal_auc: 0.9551 - val_ordinal_loss: 0.1603 - val_softmax_acc: 0.7825 - val_softmax_loss: 0.5999 - learning_rate: 3.0000e-04
# Epoch 12/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.7338 - ordinal_auc: 0.9303 - ordinal_loss: 0.2260 - softmax_acc: 0.7755 - softmax_loss: 0.6208 - val_loss: 0.6989 - val_ordinal_auc: 0.9486 - val_ordinal_loss: 0.1818 - val_softmax_acc: 0.8044 - val_softmax_loss: 0.6232 - learning_rate: 3.0000e-04
# Epoch 13/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.6802 - ordinal_auc: 0.9458 - ordinal_loss: 0.2007 - softmax_acc: 0.7882 - softmax_loss: 0.5799 - val_loss: 0.6195 - val_ordinal_auc: 0.9531 - val_ordinal_loss: 0.1564 - val_softmax_acc: 0.8003 - val_softmax_loss: 0.5488 - learning_rate: 1.5000e-04
# Epoch 14/20
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - loss: 0.6577 - ordinal_auc: 0.9318 - ordinal_loss: 0.2124 - softmax_acc: 0.7910 - softmax_loss: 0.5515 - val_loss: 0.6073 - val_ordinal_auc: 0.9517 - val_ordinal_loss: 0.1582 - val_softmax_acc: 0.8085 - val_softmax_loss: 0.5357 - learning_rate: 1.5000e-04

# %%
# model.save("effb4_dualhead_stage_13epoch.keras")

# %%
  # bật True nếu muốn fine-tune tiếp   
UNFREEZE=True
# model=tf.keras.models.load_model('models/effb4_apos2019_dualhead_stage1.keras',compile=False)

# %%
import tensorflow as tf, gc
tf.keras.backend.clear_session(); gc.collect()

# Bật memory growth (rất quan trọng)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 8
#       6 if gpus:
#       7     for gpu in gpus:
# ----> 8         tf.config.experimental.set_memory_growth(gpu, True)
#
# File ~/Documents/DoAn/myvenv/lib/python3.10/site-packages/tensorflow/python/framework/config.py:754, in set_memory_growth(device, enable)
#     729 @tf_export('config.experimental.set_memory_growth')
#     730 def set_memory_growth(device, enable):
#     731   """Set if memory growth should be enabled for a `PhysicalDevice`.
#     732
#     733   If memory growth is enabled for a `PhysicalDevice`, the runtime initialization
#    (...)
#     752     RuntimeError: Runtime is already initialized.
#     753   """
# --> 754   context.context().set_memory_growth(device, enable)
#
# File ~/Documents/DoAn/myvenv/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1998, in Context.set_memory_growth(self, dev, enable)
#    1995   return
#    1997 if self._context_handle is not None:
# -> 1998   raise RuntimeError(
#    1999       "Physical devices cannot be modified after being initialized"
#    2000   )
#    2002 self._memory_growth_map[dev] = enable
#
# RuntimeError: Physical devices cannot be modified after being initialized

# %%
 # Giai đoạn 2 (tùy chọn): unfreeze backbone 1 phần để fine-tune
    # Việc này tăng chất lượng nhưng chậm hơn trên CPU – bật nếu bạn có thời gian
    # và đã thấy loss/acc ổn định ở stage 1.

if UNFREEZE:
    print("Unfreezing backbone for fine-tuning...")
    
    
    # model.get_layer("efficientnetb4").trainable = True
    for l in model.layers:
    # freeze mặc định
        l.trainable = False
    # mở khoá các block cuối và giữ head trainable
        if l.name.startswith(("block6", "block7")) or isinstance(l, tf.keras.layers.Dense):
            l.trainable = True
        if isinstance(l, tf.keras.layers.BatchNormalization):
            l.trainable = False  # vẫn giữ BN đóng băng


        # re-compile với LR nhỏ hơn
    try:
        optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=WEIGHT_DECAY)
    except Exception:
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    

    callbacks_ft = [
            tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
            tf.keras.callbacks.ModelCheckpoint("models/effb4_apos2019_dualhead_stage2.keras",
                                               monitor="val_loss", save_best_only=True)
        ]
    
    losses = {
        "softmax": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        "ordinal": tf.keras.losses.BinaryCrossentropy(from_logits=False),
    }
    loss_weights = {"softmax": LOSS_W_SOFTMAX, "ordinal": LOSS_W_ORDINAL}

    metrics = {
        "softmax": [tf.keras.metrics.SparseCategoricalAccuracy(name="acc")],
        "ordinal": [tf.keras.metrics.AUC(name="auc", multi_label=True)],
    }

    model.compile(optimizer=optimizer, loss=losses,
                  loss_weights=loss_weights, metrics=metrics)
    print("\n=== Stage 2: Fine-tuning (unfrozen) ===")
    history2 = model.fit(
            ds_train,
            validation_data=ds_val,
            epochs=max(5, EPOCHS//2),
            callbacks=callbacks_ft,
            verbose=1
        )
print("\nDone (xây dựng & compile xong; train cơ bản đã chạy).")
# Out:
# Unfreezing backbone for fine-tuning...
#
# === Stage 2: Fine-tuning (unfrozen) ===
# Epoch 1/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 133s 262ms/step - loss: 0.8885 - ordinal_auc: 0.9286 - ordinal_loss: 0.2388 - softmax_acc: 0.7592 - softmax_loss: 0.7691 - val_loss: 0.6181 - val_ordinal_auc: 0.9559 - val_ordinal_loss: 0.1642 - val_softmax_acc: 0.8290 - val_softmax_loss: 0.5493 - learning_rate: 1.0000e-04
# Epoch 2/10
#   1/367 ━━━━━━━━━━━━━━━━━━━━ 1:13 200ms/step - loss: 0.3190 - ordinal_auc: 1.0000 - ordinal_loss: 0.0620 - softmax_acc: 0.8750 - softmax_loss: 0.2880
# 2025-08-11 10:03:18.085587: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 33554816 bytes after encountering the first element of size 33554816 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 64s 174ms/step - loss: 0.5955 - ordinal_auc: 0.9520 - ordinal_loss: 0.1652 - softmax_acc: 0.8195 - softmax_loss: 0.5129 - val_loss: 0.5482 - val_ordinal_auc: 0.9619 - val_ordinal_loss: 0.1437 - val_softmax_acc: 0.8386 - val_softmax_loss: 0.4818 - learning_rate: 1.0000e-04
# Epoch 3/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 63s 172ms/step - loss: 0.4615 - ordinal_auc: 0.9705 - ordinal_loss: 0.1323 - softmax_acc: 0.8465 - softmax_loss: 0.3954 - val_loss: 0.5766 - val_ordinal_auc: 0.9589 - val_ordinal_loss: 0.1593 - val_softmax_acc: 0.8167 - val_softmax_loss: 0.5019 - learning_rate: 1.0000e-04
# Epoch 4/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 63s 172ms/step - loss: 0.3581 - ordinal_auc: 0.9811 - ordinal_loss: 0.1070 - softmax_acc: 0.8878 - softmax_loss: 0.3046 - val_loss: 0.6891 - val_ordinal_auc: 0.9499 - val_ordinal_loss: 0.1891 - val_softmax_acc: 0.8386 - val_softmax_loss: 0.6215 - learning_rate: 1.0000e-04
# Epoch 5/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 63s 172ms/step - loss: 0.3684 - ordinal_auc: 0.9842 - ordinal_loss: 0.1102 - softmax_acc: 0.8847 - softmax_loss: 0.3132 - val_loss: 0.5889 - val_ordinal_auc: 0.9550 - val_ordinal_loss: 0.1546 - val_softmax_acc: 0.8427 - val_softmax_loss: 0.5298 - learning_rate: 1.0000e-04
# Epoch 6/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 63s 173ms/step - loss: 0.1949 - ordinal_auc: 0.9925 - ordinal_loss: 0.0613 - softmax_acc: 0.9403 - softmax_loss: 0.1642 - val_loss: 0.6383 - val_ordinal_auc: 0.9485 - val_ordinal_loss: 0.1678 - val_softmax_acc: 0.8427 - val_softmax_loss: 0.5833 - learning_rate: 5.0000e-05
# Epoch 7/10
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 63s 173ms/step - loss: 0.1519 - ordinal_auc: 0.9952 - ordinal_loss: 0.0500 - softmax_acc: 0.9587 - softmax_loss: 0.1269 - val_loss: 0.6346 - val_ordinal_auc: 0.9556 - val_ordinal_loss: 0.1600 - val_softmax_acc: 0.8345 - val_softmax_loss: 0.5809 - learning_rate: 5.0000e-05
#
# Done (xây dựng & compile xong; train cơ bản đã chạy).

# %%
# !ipynb-py-convert structure_model_v2.ipynb plot.py
